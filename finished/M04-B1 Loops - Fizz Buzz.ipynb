# %% [markdown]
# # M2-A1 Loops - Fizz Buzz
#
# # Instructions:
# Output the numbers 1-user inputed number, however:
# - for every number divisible by 3 output 'Fizz'
# - for every number divisible by 5 output 'Buzz'
# - for every number divisible by 3 and 5 output 'FizzBuzz'
#
# **Bold** indicates input from the console.
#
# ### Expected sample output:
# Enter number:<br>
# **25**<br>
# 1<br>
# 2<br>
# Fizz<br>
# 4<br>
# Buzz<br>
# Fizz<br>
# 7<br>
# 8<br>
# Fizz<br>
# Buzz<br>
# 11<br>
# Fizz<br>
# 13<br>
# 14<br>
# FizzBuzz<br>
# 16<br>
# 17<br>
# Fizz<br>
# 19<br>
# Buzz<br>
# Fizz<br>
# 22<br>
# 23<br>
# Fizz<br>
#
# ### Expected sample output:
# Enter number:<br>
# **50**<br>
# 1<br>
# 2<br>
# Fizz<br>
# 4<br>
# Buzz<br>
# Fizz<br>
# 7<br>
# 8<br>
# Fizz<br>
# Buzz<br>
# 11<br>
# Fizz<br>
# 13<br>
# 14<br>
# FizzBuzz<br>
# 16<br>
# 17<br>
# Fizz<br>
# 19<br>
# Buzz<br>
# Fizz<br>
# 22<br>
# 23<br>
# Fizz<br>
# Buzz<br>
# 26<br>
# Fizz<br>
# 28<br>
# 29<br>
# FizzBuzz<br>
# 31<br>
# 32<br>
# Fizz<br>
# 34<br>
# Buzz<br>
# Fizz<br>
# 37<br>
# 38<br>
# Fizz<br>
# Buzz<br>
# 41<br>
# Fizz<br>
# 43<br>
# 44<br>
# FizzBuzz<br>
# 46<br>
# 47<br>
# Fizz<br>
# 49<br>

# %%
#Write your Python code here

print("Enter number:")
num = int(input())
for x in range(num):
    if x != 0:
        if x % 3 == 0 and x % 5 == 0:
            print("FizzBuzz")
        elif x % 3 == 0:
            print("Fizz")
        elif x % 5 == 0:
            print("Buzz")
        else:
            print(x)
# Out:
# Enter number:
#  25
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
